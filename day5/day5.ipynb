# %%
x = 'this is string '
print(x)
# Out:
# this is string

# %%
y ="this is string"
print(y)
# Out:
# this is string

# %%
z =""" nothing is possible
the word itself
i'm possible
"""
print(z)
# Out:
#  nothing is possible
# the word itself
# i'm possible

# %%
a = "shlok"
print(a)
# Out:
# shlok

# %%
print(a[0])
print(a[1])
print(a[2])
print(a[3])
print(a[4])
# Out:
# s
# h
# l
# o
# k

# %%
b = "PROGRAMMING"
b = " j a v a "
print(b)
# Out:
#  j a v a

# %%
word = "PROGRAMMING" #positive slincing
print(word[0:11])
print(word[0: ])
print(word[ :11])
print(word[0:3])
print(word[3:7])
print(word[7:11])
# Out:
# PROGRAMMING
# PROGRAMMING
# PROGRAMMING
# PRO
# GRAM
# MING

# %%
print(word[-3:-8])  #negative slincing

# %%
print(word[0:11:2])
print(word[0:11:3])
print(word[0:11:4])
print(word[ ::2])
print(word[0:11:3])
print(word[ ::-11])
print(word[ ::-1])
# Out:
# PORMIG
# PGMN
# PRI
# PORMIG
# PGMN
# G
# GNIMMARGORP

# %%
word ="PROGRAMMING"
len(word)
# Out:
# 11

# %%
word.upper()
# Out:
# 'PROGRAMMING'

# %%
word.lower()
# Out:
# 'programming'

# %%
x = input("enter your name ")
print(x)
# Out:
# enter your name shlok bahe
# shlok bahe

# %%
x.strip()
# Out:
# 'shlok bahe'

# %%
word.replace('PRO', 'FRO')
# Out:
# 'FROGRAMMING'

# %%
name = "my coolage name is "
name_split = name.split()
name.split()
# Out:
# ['my', 'coolage', 'name', 'is']

# %%
word.find('P')
# Out:
# 0

# %%
word.count('M')
# Out:
# 2

# %%
word.startswith("PRO")
# Out:
# True

# %%
word.endswith("Img")
# Out:
# False
