# %%
x = [10 , 20 , 30 , 40 , 50]
print(x)
# Out:
# [10, 20, 30, 40, 50]

# %%
list2= ["apple" , "mango" , "banana"]
print(list2)
# Out:
# ['apple', 'mango', 'banana']

# %%
list3= [12, 23.6533, True, "python"]
print(list3[-1])
# Out:
# python

# %%
list3= [12, 23.6533, True, "python"]
list3[0]= 100
print(list3)
# Out:
# [100, 23.6533, True, 'python']

# %%
list3[:3]
# Out:
# [100, 23.6533, True]

# %%
name = "empty python"
print(name)
# Out:
# empty python

# %%
print(name[0:])
print(name[0:])
print(name[:])
print(name[0:12])
print(name[::-1])
# Out:
# empty python
# empty python
# empty python
# empty python
# nohtyp ytpme

# %%
x = [10 , 20 , 30 , 40 , 50 ]
print(x)
# Out:
# [10, 20, 30, 40, 50]

# %%
x.append(60)
print(x)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
x.insert(2,50)
print(x)
# Out:
# [10, 20, 50, 30, 40, 50, 60]

# %%
x.remove(50)
print(x)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
x.pop(2)
print(x)
# Out:
# [10, 20, 40, 50, 60]

# %%
x.sort()
print(x)
# Out:
# [10, 20, 40, 50, 60]

# %%
x.reverse()
print(x)
# Out:
# [60, 50, 40, 20, 10]

# %%
len(x)
# Out:
# 5

# %% [markdown]
# Tuple

# %%
t1 = (10, 29.89 , True , "apple")
print(t1)
# Out:
# (10, 29.89, True, 'apple')

# %%
t1.count(10)
# Out:
# 1

# %%
t1.index("apple")
# Out:
# 3
