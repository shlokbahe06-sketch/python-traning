# %%
print("hii")
# Out:
# hii

# %%
age = 18
name = "shlok"
x = 'A'
y = True

# %%
print(age)
print(name)
print(x)
print(y)
# Out:
# 18
# shlok
# A
# True

# %%
print(type(age))
print(type(name))
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'bool'>

# %%
print('c') #this is single line comment
# Out:
# c

# %%
"""print("hello")
print("hello")
print("hello")
print("hello")
"""
# Out:
# 'print("hello")\nprint("hello")\nprint("hello")\nprint("hello")\n'

# %%
# operators
# special symbols 
a=10
b=5
print(a+b)
# Out:
# 15

# %%
A = "shlok"
B = "bahe"
print(A+B)
# Out:
# shlokbahe

# %%
a=15
b=2
print(a*b)
# Out:
# 30

# %%
a=50
b=15
print(a-b)
# Out:
# 35

# %%
a=2
b=15
print(a%b)
# Out:
# 2
