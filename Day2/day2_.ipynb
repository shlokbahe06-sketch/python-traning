# %%
#build-in module
import math as me
print(me.sqrt(25))
print(me.pow(3,2))
# Out:
# 5.0
# 9.0

# %%
print(me.sqrt(780))
# Out:
# 27.92848008753788

# %%
# !pip install pyjokes

# %%
import pyjokes

# %%
pyjokes.get_joke()
# Out:
# 'Computer programmers do it byte by byte.'

# %%
# print("this is the second day of python training")

# %%
import math as me
me.pow(4,2)
# Out:
# 16.0
