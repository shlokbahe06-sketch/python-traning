# %%
import random

# %%
print(random.randint(1,6000))
# Out:
# 1207

# %%
import datetime
import zoneinfo

# %%
print(datetime.date.today())
# Out:
# 2026-08-21

# %%
print(datetime.datetime.now(zoneinfo.ZoneInfo("Asia/Kolkata")))
# Out:
# 2026-08-22 00:40:49.712416+05:30

# %%
a,b,c,d=10,20,30,40

# %%
print(a,b,c,d)
# Out:
# 10 20 30 40

# %%
a=10
b=20
c=30
d=40

# %%
print(a)
print(b)
print(c)
print(d)
# Out:
# 10
# 20
# 30
# 40

# %%
name="shlok"
age=20
sgpa=8.50

# %%
name,age,sgpa
# Out:
# ('shlok', 20, 8.5)

# %%
print(f"my name is {name} my age is {age}, my cgpa is {sgpa}")
# Out:
# my name is shlok my age is 20, my cgpa is 8.5

# %%
collage="tgpcet"
deptstudent=160

# %%
print(f"my collage is {collage}, and dept student is {deptstudent}")
# Out:
# my collage is tgpcet, and dept student is 160

# %%
y=1234567
print(type(str(y)))
# Out:
# <class 'str'>
