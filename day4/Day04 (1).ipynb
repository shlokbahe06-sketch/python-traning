# %%
x = "16122006"
type(x)
# Out:
# str

# %%
10+30
# Out:
# 40

# %%
5-25
# Out:
# -20

# %%
4*3
# Out:
# 12

# %%
10/ 3 #this is division
# Out:
# 3.3333333333333335

# %%
10//3 #float division
# Out:
# 3

# %%
10%3 #modulus operator
# Out:
# 1

# %%
10**2 #power
# Out:
# 100

# %%
a = 10
b = 20
a = b #assigment operator

# %%
10 == 10 #check equal
# Out:
# True

# %%
10 == 5
# Out:
# False

# %%
10 !=10 #check not equal
# Out:
# False

# %%
10 != 5
# Out:
# True

# %%
10 > 5 #greater
# Out:
# True

# %%
10 < 5
# Out:
# False

# %%
10 >= 10 #greater than equals to
# Out:
# True

# %%
10 <= 20 #smaller than equals to
# Out:
# True

# %%
cond1 = 10 > 5
cond2 = 10 > 20
print(cond1)
print(cond2)
# Out:
# True
# False

# %%
cond1 and cond2
# Out:
# False

# %%
cond1 or cond2
# Out:
# True

# %%
not 10 < 5
# Out:
# True

# %%
#assigment opretor

# %%
age = 10

# %%
age = age + 2 # add and assign operator

# %%
age +=2
age
# Out:
# 20

# %%
age *=2 #multiply and assign operator
age
# Out:
# -16.0

# %%
age *=2
age
# Out:
# -16.0

# %%
age //=2
age
# Out:
# -8.0

# %%
x =int(input("enter your numbers"))
# Out:
# enter your numbers45

# %%
print(x)
print (type(x))
# Out:
# 45
# <class 'int'>

# %%
x + 2
# Out:
# 47

# %%
a=35
b=45

# %%
print(a+b)
print(a-b)
print(a/b)
print(a%b)
# Out:
# 80
# -10
# 0.7777777777777778
# 35

# %%
math=int(input("enter  marks is: "))
physics =int(input("enter marks is: "))
chem =int(input("enter marks is: "))
# Out:
# enter  marks is: 75
# enter marks is: 85
# enter marks is: 65

# %%
total= math+physics+chem
print("total marks is",total)

average=total//3
print("average marks is",average)
# Out:
# total marks is 225
# average marks is 75

# %%
numbers = int(input("enter a numbers: "))

if numbers % 2 == 0:
  print("Even")
else:
  print("odd")
# Out:
# enter a numbers: 13
# odd

# %%
age = int(input("Enter a age: "))

if age >=18:
  print("eligible for vote")
else:
    print("not eligible")
# Out:
# Enter a age: 45
# eligible for vote

# %%
temperature = float(input("enter a temperature"))
fara =(temperature *9/5) + 32
print (fara)
# Out:
# enter a temperature45.5
# 113.9
